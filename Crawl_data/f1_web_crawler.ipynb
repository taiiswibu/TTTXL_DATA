# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.formula1.com/en/results.html/2023/drivers.html'
response = requests.get(url)

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table', class_='resultsarchive-table')
    # Extract the rows of the table
    rows = table.find_all('tr')
    
    for row_id, row in enumerate(rows):
        columns = row.find_all('td')
        # print(f"row={row_id}: {columns}")
        if columns:
            position = columns[1].text.strip()
            driver_name = columns[2].text.strip().split('\n')
            driver_name = ' '.join(driver_name[:-1])
            
            nationality = columns[3].text.strip()
            car = columns[4].text.strip()
            pts = columns[5].text.strip()
            print(f"Position: {position}\
                    \nDriver Name: {driver_name}\
                    \nNationality: {nationality}\
                    \nCar: {car}\
                    \nPoints: {pts}\n\n")
# Out:
# Position: 1
# Driver Name: Max Verstappen
# Nationality: NED
# Car: Red Bull Racing Honda RBPT
# Points: 433
#
#
# Position: 2
# Driver Name: Sergio Perez
# Nationality: MEX
# Car: Red Bull Racing Honda RBPT
# Points: 224
#
#
# Position: 3
# Driver Name: Lewis Hamilton
# Nationality: GBR
# Car: Mercedes
# Points: 194
#
#
# Position: 4
# Driver Name: Fernando Alonso
# Nationality: ESP
# Car: Aston Martin Aramco Mercedes
# Points: 183
#
#
# Position: 5
# Driver Name: Carlos Sainz
# Nationality: ESP
# Car: Ferrari
# Points: 153
#
#
# Position: 6
# Driver Name: Charles Leclerc
# Nationality: MON
# Car: Ferrari
# Points: 145
#
#
# Position: 7
# Driver Name: Lando Norris
# Nationality: GBR
# Car: McLaren Mercedes
# Points: 136
#
#
# Position: 8
# Driver Name: George Russell
# Nationality: GBR
# Car: Mercedes
# Points: 132
#
#
# Position: 9
# Driver Name: Oscar Piastri
# Nationality: AUS
# Car: McLaren Mercedes
# Points: 83
#
#
# Position: 10
# Driver Name: Lance Stroll
# Nationality: CAN
# Car: Aston Martin Aramco Mercedes
# Points: 47
#
#
# Position: 11
# Driver Name: Pierre Gasly
# Nationality: FRA
# Car: Alpine Renault
# Points: 46
#
#
# Position: 12
# Driver Name: Esteban Ocon
# Nationality: FRA
# Car: Alpine Renault
# Points: 44
#
#
# Position: 13
# Driver Name: Alexander Albon
# Nationality: THA
# Car: Williams Mercedes
# Points: 23
#
#
# Position: 14
# Driver Name: Valtteri Bottas
# Nationality: FIN
# Car: Alfa Romeo Ferrari
# Points: 10
#
#
# Position: 15
# Driver Name: Nico Hulkenberg
# Nationality: GER
# Car: Haas Ferrari
# Points: 9
#
#
# Position: 16
# Driver Name: Zhou Guanyu
# Nationality: CHN
# Car: Alfa Romeo Ferrari
# Points: 6
#
#
# Position: 17
# Driver Name: Yuki Tsunoda
# Nationality: JPN
# Car: AlphaTauri Honda RBPT
# Points: 3
#
#
# Position: 18
# Driver Name: Kevin Magnussen
# Nationality: DEN
# Car: Haas Ferrari
# Points: 3
#
#
# Position: 19
# Driver Name: Liam Lawson
# Nationality: NZL
# Car: AlphaTauri Honda RBPT
# Points: 2
#
#
# Position: 20
# Driver Name: Logan Sargeant
# Nationality: USA
# Car: Williams Mercedes
# Points: 0
#
#
# Position: 21
# Driver Name: Nyck De Vries
# Nationality: NED
# Car: AlphaTauri Honda RBPT
# Points: 0
#
#
# Position: 22
# Driver Name: Daniel Ricciardo
# Nationality: AUS
# Car: AlphaTauri Honda RBPT
# Points: 0

# %%
import csv

# Tạo một tên file CSV để lưu trữ dữ liệu
csv_filename = "race_results.csv"

# Mở file CSV để ghi
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    # Tạo đối tượng CSV writer
    csv_writer = csv.writer(csv_file)

    # Ghi tiêu đề của cột
    csv_writer.writerow(['Position', 'Driver Name', 'Nationality', 'Car', 'Points'])

    # Lặp qua các dòng và ghi dữ liệu vào file CSV
    for row_id, row in enumerate(rows):
        columns = row.find_all('td')
        if columns:
            position = columns[1].text.strip()
            driver_name = columns[2].text.strip().split('\n')
            driver_name = ' '.join(driver_name[:-1])
            nationality = columns[3].text.strip()
            car = columns[4].text.strip()
            pts = columns[5].text.strip()

            # Ghi dữ liệu vào file CSV
            csv_writer.writerow([position, driver_name, nationality, car, pts])

print(f"Dữ liệu đã được xuất ra file CSV: {csv_filename}")
# Out:
# Dữ liệu đã được xuất ra file CSV: race_results.csv
